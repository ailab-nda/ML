# %% [markdown]
# <a href="https://colab.research.google.com/github/ailab-nda/ML/blob/main/Youtube_Downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Youtubeダウンロード

# %% [markdown]
# ## ライブラリのインストール

# %%
# !pip install yt-dlp
# !npm install -g deno

# %% [markdown]
# ## 音声(mp3)のダウンロード

# %%
# !yt-dlp -x --audio-format mp3 --remote-components ejs:npm "https://www.youtube.com/watch?v=pAn56UUI4yg"

# %% [markdown]
# ## ビデオ(mp4)のダウンロード

# %%
# !yt-dlp --merge-output-format mp4 --remote-components ejs:npm "https://www.youtube.com/watch?v=pAn56UUI4yg"
