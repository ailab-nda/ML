# %% [markdown]
# <a href="https://colab.research.google.com/github/ailab-nda/ML/blob/main/WebScraping_short.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web スクレイピング
#
# 出典　https://code.dividable.net/tutorials/python-scraping-blog/

# %%
import pandas as pd
import csv
import time
import random
import re
import json
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## WebページのHTMLを取得

# %%
response = requests.get("https://honnobi.com/proverb-roland")
html_doc = response.text
soup = BeautifulSoup(html_doc, 'html.parser')
#print(soup.prettify())

# %% [markdown]
# ## 欲しい部分を抽出

# %%
# ここはソースを見て必要なところを決める
tags = soup.find_all("strong")
for i in tags:
    print(i.text)
# Out:
# 現代ホスト界の帝王
# ローランドの名言
# 黄色
# 世の中には2種類の男しかいない
# 俺か、俺以外か
# 緊張は成長痛
# 生まれたときから（自信は）あった
# 俳句が何文字でも使って良かったら、そこにロマンとか何もない
# 今日の自分より明日の自分
# 明日の自分より明後日の自分
# 俺は目指さない、目指されるんだ
# 年齢は、どれだけ生きたかは教えてくれても、どう生きたかは教えてくれないだろ？
# 俺はローランドだからね
# コンビニには手を染めないよ
# 反骨心が俺の恩人であり相棒さ
# 頑張っていたら、みんなにありがとうと思える日がくる
# ローランドが下を向くのは、出勤時に靴を履くときだけさ
# 白い目で見られたって気にしないね
# 白は何色にでも染められる
# 月があんなにも美しいのは誰のモノでもないからさ
# あぁ皆様！
# 生まれてきてあげて、どういたしまして！
# 朝起きたらシャワー浴びる前に拍手喝采浴びがち
# 俺には負けの概念がないんだ
# 今は勝ちの途中ってだけさ
# 逆境は確かに辛いが、大切な相手に愛情や忠誠心を示す事ができるタイミングでもある
# 人間の本心は苦しい時によく見えるものだから
# どんな事でも、負けない唯一の方法は『最初から戦わない事』しかないよ
# ローランドは名前じゃない、概念だ
# 日頃オーラ出し過ぎて飽きたし
# そろそろオーロラでも出そーかなー
# もし世界が完璧だったら君達にローランドは必要ないだろ？
# 立川市も俺を目の前にしたら、座る
# ･･･まあ俺
# 機種変する、ぐらいの感覚で歴史変えちゃう癖あるからねぇ
# ROLANDがこの世にいる限りもう10月を神無月だなんて言わせない
# 若者にとっての「ランド」の定義が「ディズニーランド」から「ローランド」に変わるのに、そう時間はいらないさ
# ノーが言えない人のイエスには価値はない
# 嫌いが言えない人のイエスには価値がない
# 最高の物がいつも最高の扱いを受けるとは限らないよ
# 子供にはロマネ・コンティを出すよりもコーラを出した方が喜ばれるのと同じ
# 王道とはROLANDが歩いてきた道と、それからROLANDが今後歩く予定の道の総称
# 幸せは独り占めするよりもシェアした方が長く続く
# 下手なテレビを観るより、鏡を見ている方が面白い
# ...

# %% [markdown]
# ## ファイルに保存

# %%
f = open("roland.txt","w")
for i in tags:
    f.write(i.text+"\n")
f.close()
